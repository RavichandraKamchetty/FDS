# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var = sns.load_dataset("penguins")
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(var["flipper_length_mm"], bins = [170, 180, 190, 200, 210, 220, 230, 240], kde = True, rug = True)
plt.show()

# Kernel Density Estimation (KDE): A way to estimate the probability density function of a 
#                                 random variable by smoothing the histogram. It involves placing a kernel 
#                                 (a smooth function, often a Gaussian) at each data point and 
#                                 summing up these kernels to create a smooth curve.

# A rug plot is a simple representation of individual data points along the x-axis of the plot. 
# It places a small vertical tick at each data point, providing a visual indicator of the data distribution. 
# Rug plots are often used in combination with histograms or 
# kernel density plots to show the actual data points on the axis.
# Out:
# /Users/ravichandra/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "penguins" dataset
var = sns.load_dataset("penguins")

# Set the style
sns.set(style="whitegrid")

# Create a density plot for the "bill_length_mm" column
sns.kdeplot(data=var, x="bill_length_mm", fill=True, common_norm=False)

# Add title and labels
plt.title("Density Plot of Bill Length")
plt.xlabel("Bill Length (mm)")
plt.ylabel("Density")

# Show the plot
plt.show()
